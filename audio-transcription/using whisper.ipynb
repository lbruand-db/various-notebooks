# %% [markdown]
# # Audio transcription using whisper library
#
# Has been tested on databricks serverless

# %%
import sys
print("Python version:", sys.version)
# Check key package versions, e.g., databricks-connect
import pkg_resources
print(f"databricks-connect version: {pkg_resources.get_distribution("databricks-connect").version}")

# %%
model_uc_path = 'system.ai.whisper_large_v3'

# %%
# %pip install ffmpeg ffmpeg-binaries==1.0.1

# %%
# !pip install -U openai-whisper

# %%
import whisper

# %%
model = whisper.load_model("turbo")

# %%
# !wget https://www.nasa.gov/wp-content/uploads/2015/01/590325main_ringtone_kennedy_WeChoose.mp3

# %%
# %sh
which ffmpeg

# %%
result = model.transcribe("590325main_ringtone_kennedy_WeChoose.mp3")

# %%
print(result)
