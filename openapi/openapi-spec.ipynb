# %%
model_endpoint = "databricks-llama-4-maverick"

# %%
DATABRICKS_TOKEN = dbutils.notebook.entry_point.getDbutils().notebook().getContext().apiToken().get()
workspaceUrl = dbutils.notebook.entry_point.getDbutils().notebook().getContext().apiUrl().get()

# %%
import os
import requests
url = workspaceUrl + f"/api/2.0/serving-endpoints/{model_endpoint}/openapi"

headers = {'Authorization': f'Bearer {DATABRICKS_TOKEN}', 'Content-Type': 'application/json'}
response = requests.request(method='GET', headers=headers, url=url, )
import json
display(json.loads(response.text))
